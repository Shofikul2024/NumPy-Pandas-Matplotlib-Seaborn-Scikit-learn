# %% [markdown]
#  Pandas হল Python-এর একটি অত্যন্ত জনপ্রিয় এবং শক্তিশালী লাইব্রেরি, যা ডেটা ম্যানিপুলেশন এবং বিশ্লেষণের জন্য ব্যবহৃত হয়। এটি মূলত DataFrame এবং Series নামক ডেটা স্ট্রাকচার ব্যবহার করে ডেটাকে প্রক্রিয়া এবং বিশ্লেষণ করার জন্য তৈরি হয়েছে। Pandas ডেটা বিশ্লেষণকে সহজ এবং দ্রুত করে তোলে, এবং এটি ডেটাবেস, CSV, Excel, SQL এবং অন্যান্য ফাইল ফরম্যাট থেকে ডেটা আমদানি এবং রপ্তানি করার জন্য শক্তিশালী টুলস প্রদান করে।
#
# Pandas এর প্রধান বৈশিষ্ট্য:
# DataFrame: এটি একটি টেবিল আকারে ডেটা স্ট্রাকচার, যা সারি এবং কলাম সহ ডেটাকে সঞ্চালন ও বিশ্লেষণ করতে সহায়ক।
# Series: এটি একটি একক কলাম বিশিষ্ট ডেটা স্ট্রাকচার, যা মূলত একক ডেটা সিরিজ ধারণ করতে ব্যবহৃত হয়।
# ডেটা ক্লিনিং: মিসিং ডেটা পূর্ণ করা, ডেটা ফিল্টারিং, ডেটা কনভার্সন, এবং অপ্রয়োজনীয় ডেটা অপসারণের জন্য Pandas অত্যন্ত কার্যকর।
# গ্রুপবাই অপারেশন: একসাথে ডেটা গ্রুপ করা এবং বিভিন্ন পরিসংখ্যান অপারেশন সম্পাদন করা যায়।
# টাইম সিরিজ: Pandas টাইম সিরিজ ডেটার সাথে কাজ করতে সক্ষম, যা আর্থিক এবং বৈজ্ঞানিক বিশ্লেষণে অত্যন্ত সহায়ক।
# ডেটার ফরম্যাটিং এবং ম্যানিপুলেশন: ডেটা ট্রান্সফরমেশন, সোর্টিং, এবং কমপ্লেক্স ক্যালকুলেশন করতে সহায়ক।

# %% [markdown]
# পানডাস সিরিজ (Pandas Series)
# পানডাস সিরিজ একটি একমাত্রিক (one dimensional) অ্যারে যেটা যেকোন ধরনের ডাটা সংরক্ষণ করতে পারে। পূর্বে আমরা দেখেছি যে অ্যারে তে একই ডাটা টাইপের ভ্যালু রাখতে হয় কিন্তু এখানে সেই বাধ্যবাধকতা নেই। আমরা যারা টেবিল ডাটা যেমন মাইক্রোসফট এক্সেল ( Microsoft Excel) নিয়ে কাজ করেছি তাদের কাছে পানডাস বুঝতে একটু সুবিধা হবে। টেবিলের এক একটি কলামকে আমরা একটা সিরিজ বলতে পারি। একটি উদাহরণ দেখে নিই-

# %%
import pandas as pd

# %%
# pandas is already imported in earlier cells
data = [1, 2, 'three']

pd_data = pd.Series(data)

print(pd_data[1])  # Accessing by index
print(pd_data)
# Out:
# 2
# 0        1
# 1        2
# 2    three
# dtype: object

# %%
import pandas as pd

# ডেটা লোড করা (এখানে একটি সিম্পল ডেটাসেট ব্যবহার করা হয়েছে)
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [24, 27, 22],
        'City': ['New York', 'San Francisco', 'Chicago']}

# DataFrame তৈরি
df = pd.DataFrame(data)

# DataFrame প্রদর্শন
print(df)
# Out:
#       Name  Age           City
# 0    Alice   24       New York
# 1      Bob   27  San Francisco
# 2  Charlie   22        Chicago

# %%
# লেবেল (Label)
# লেবেল তৈরি করার জন্য index আরগুমেন্ট এর ভিতর লেবেলের নাম দিয়ে দিলেই হয়।
 
import pandas as pd
 
data = [1, 2, 'three']
 
pd_data = pd.Series(data, index=['First','Second','Third'])
 
print(pd_data)
# Out:
# First         1
# Second        2
# Third     three
# dtype: object

# %% [markdown]
# ডাটাফ্রেম (DataFrame)
# পানডাস ডাটাফ্রেম একটি দ্বিমাত্রিক (two dimensional) ডাটা স্ট্রাকচার অর্থাৎ এখানে একটি সারি থাকবে এবং একটি স্তম্ভ (column) থাকবে। আমরা যদি একটি টেবিল ডাটা কে কল্পনা করি তাহলে সমগ্র টেবিলটাই একটি ডাটাফ্রেম। একটি উদাহরণ দেখে নিই-

# %%
 
import pandas as pd
 
data = {"Course ID": ['CSE10', 'CSE20', 'CSE30', 'CSE40'],
        "GPA": [4, 3.68, 3.55,3.98]
}
 
pd_data = pd.DataFrame(data)
 
print(pd_data)
# Out:
#   Course ID   GPA
# 0     CSE10  4.00
# 1     CSE20  3.68
# 2     CSE30  3.55
# 3     CSE40  3.98

# %%
# নির্দিষ্ট কোন সারিকে অ্যাক্সেস করা
# পূর্বে আমরা জেনেছি যে পানডাস এর সিরিজ হচ্ছে এক একটি কলাম; কিন্তু এমন যদি হয় যে একটি সারি নিয়ে কাজ করতে হবে তখন আমরা loc() ব্যবহার করতে পারি। উপরের উদাহরণটিকে ব্যবহার করে বিষয়টি বুঝে নিই-

 
import pandas as pd
 
data = {"Course ID": ['CSE10', 'CSE20', 'CSE30', 'CSE40'],
        "GPA": [4, 3.68, 3.55,3.98]
}
 
pd_data = pd.DataFrame(data)
 
print(pd_data.loc[1])
# Out:
# Course ID    CSE20
# GPA           3.68
# Name: 1, dtype: object

# %% [markdown]
# # DataFrame এবং Series এর ধারণা  start

# %% [markdown]
# Python-এর Pandas লাইব্রেরি ডেটা বিশ্লেষণ এবং প্রক্রিয়াকরণের জন্য দুটি প্রধান ডেটা স্ট্রাকচার সরবরাহ করে: DataFrame এবং Series। এগুলির সাহায্যে আপনি সহজে টেবিল আকারে ডেটা পরিচালনা করতে পারেন, যেমন কলাম এবং সারি নিয়ে কাজ করা। এদের মধ্যে পার্থক্য এবং ব্যবহার বুঝতে হলে প্রথমে এদের মৌলিক ধারণা জানা দরকার।

# %% [markdown]
# ১. Series:
# Series হল Pandas এর একটি মৌলিক ডেটা স্ট্রাকচার, যা একমাত্র একটি ভেক্টরের মতো কাজ করে, এবং এটি একটি একমাত্র কলামের ডেটার প্রতিনিধিত্ব করে। Series একটি একমাত্রিক (1D) আ্যারে যা লেবেলযুক্ত ডেটা ধারণ করে।

# %% [markdown]
# মৌলিক বৈশিষ্ট্য:
# এটি একমাত্র ডেটা কলাম ধারণ করে (যেমন, একটি মাত্র তালিকা বা অ্যারে)।
# প্রতিটি উপাদানের সাথে একটি index (ইন্ডেক্স) থাকে যা তার অবস্থান নির্দেশ করে।
# Series সাধারণত সংখ্যাত্মক, স্ট্রিং অথবা অন্য যে কোন ডেটা টাইপ ধারণ করতে পারে।
#
#
# উদাহরণ:

# %%
import pandas as pd

# একটি সিম্পল Series তৈরি করা
data = [10, 20, 30, 40, 50]
series = pd.Series(data)

# সিরিজটি দেখানো
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
#  এখানে, সিরিজটি একটি একমাত্র ডেটা কলাম ধারণ করে, এবং প্রতিটি উপাদানের একটি ইন্ডেক্স (0, 1, 2, 3, 4) থাকে।

# %% [markdown]
# Index সহ Series:
# Series তৈরি করতে ইন্ডেক্স প্রদান করা সম্ভব:

# %%
series_with_index = pd.Series(data, index=["a", "b", "c", "d", "e"])
print(series_with_index) # সিরিজটি ইন্ডেক্স সহ দেখানো
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# এখানে, প্রতিটি ডেটা উপাদান একটি নির্দিষ্ট ইন্ডেক্স (a, b, c, d, e) দ্বারা চিহ্নিত।

# %% [markdown]
# ২. DataFrame:
# DataFrame হল একটি দ্বিমাত্রিক (2D) টেবিল ডেটা স্ট্রাকচার, যা কলাম এবং সারি নিয়ে গঠিত। এটি এক বা একাধিক Series এর সমষ্টি, এবং প্রতিটি Series একটি নির্দিষ্ট কলাম প্রতিনিধিত্ব করে।
#
# মৌলিক বৈশিষ্ট্য:
#
# এটি একাধিক কলাম ধারণ করতে পারে,
#
# যেখানে প্রতিটি কলাম একটি Series।
# প্রতিটি কলামের জন্য একটি আলাদা index থাকতে পারে।
#
# DataFrame সাধারণত ডেটা বিশ্লেষণ, টেবিল আকারে ডেটা দেখানো এবং পরিচালনার জন্য ব্যবহৃত হয়।
# উদাহরণ:

# %%
import pandas as pd

# ডেটার একটি dictionary তৈরি করা
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

# DataFrame তৈরি করা
df = pd.DataFrame(data)

# DataFrame প্রদর্শন
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4      Eva   29      Phoenix

# %% [markdown]
# এখানে, DataFrame তে তিনটি কলাম (Name, Age, City) এবং পাঁচটি সারি রয়েছে। প্রতিটি কলামের একটি নাম (যেমন, "Name", "Age", "City") এবং প্রতিটি সারির একটি ইন্ডেক্স (0, 1, 2, 3, 4) রয়েছে।

# %% [markdown]
# Index সহ DataFrame:
# DataFrame এ কলামের নাম এবং সারির ইন্ডেক্স কাস্টমাইজ করা যেতে পারে:

# %%
df_custom_index = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e'])
print(df_custom_index)
# Out:
#       Name  Age         City
# a    Alice   24     New York
# b      Bob   27  Los Angeles
# c  Charlie   22      Chicago
# d    David   32      Houston
# e      Eva   29      Phoenix

# %% [markdown]
# # DataFrame এবং Series এর মধ্যে পার্থক্য

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# সারাংশ
# Series: এটি Pandas এর একটি একমাত্রিক ডেটা স্ট্রাকচার, যা এক কলামের ডেটা ধারণ করে। এর সাথে একটি ইনডেক্স থাকে, যা প্রতিটি উপাদানকে চিহ্নিত করে।
# DataFrame: এটি Pandas এর একটি দ্বিমাত্রিক ডেটা স্ট্রাকচার, যা একাধিক কলাম এবং সারি নিয়ে গঠিত। এটি Series-এর একটি সংগ্রহ যা একত্রে ডেটা টেবিলের মতো কাজ করে।
# Pandas DataFrame এবং Series উভয়ই ডেটা বিশ্লেষণ ও প্রক্রিয়াকরণের জন্য অত্যন্ত গুরুত্বপূর্ণ, এবং এগুলির সাহায্যে আপনি সহজে ডেটা ম্যানিপুলেশন এবং বিশ্লেষণ করতে পারেন।

# %% [markdown]
# # DataFrame এবং Series এর ধারণা  end

# %% [markdown]
# # DataFrame থেকে Data Selection এবং Filtering start

# %% [markdown]
# Pandas একটি জনপ্রিয় Python লাইব্রেরি যা DataFrame নামক একটি ডেটা স্ট্রাকচার ব্যবহার করে ডেটাকে টেবিল আকারে সংরক্ষণ এবং পরিচালনা করার জন্য। DataFrame থেকে ডেটা নির্বাচন (Data Selection) এবং ফিল্টারিং (Filtering) হল ডেটা বিশ্লেষণের গুরুত্বপূর্ণ অংশ, যা বিভিন্ন পরিস্থিতিতে প্রয়োজনীয় ডেটা বের করতে সহায়তা করে।
#
# এখানে Pandas DataFrame থেকে ডেটা সিলেকশন এবং ফিল্টারিং সম্পর্কিত বিভিন্ন পদ্ধতি বিস্তারিতভাবে আলোচনা করা হল।

# %% [markdown]
# ১. DataFrame তৈরি
# প্রথমে একটি সাধারণ DataFrame তৈরি করি:

# %%
import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

# DataFrame দেখানো
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4   Edward   29      Phoenix

# %% [markdown]
# ২. Data Selection (ডেটা নির্বাচন)
# DataFrame থেকে নির্দিষ্ট কলাম বা সারি নির্বাচন করার বিভিন্ন পদ্ধতি আছে।
#
# ১.1 একটি কলাম নির্বাচন:

# %%
# 'Name' কলাম নির্বাচন
import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

# DataFrame দেখানো
# print(df)



name_column = df['Name']

print(name_column)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4     Edward
# Name: Name, dtype: object

# %% [markdown]
# ২.Data Selection (ডেটা নির্বাচন)
# DataFrame থেকে নির্দিষ্ট কলাম বা সারি নির্বাচন করার বিভিন্ন পদ্ধতি আছে।
#
# ১.1 একটি কলাম নির্বাচন:

# %%
# 'Name' কলাম নির্বাচন
name_column = df['Name']
print(name_column)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4     Edward
# Name: Name, dtype: object

# %% [markdown]
# ১.2 একাধিক কলাম নির্বাচন:

# %%
# 'Name' এবং 'Age' কলাম নির্বাচন

import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

# DataFrame দেখানো
# print(df)

selected_columns = df[['Name', 'Age']]    # একাধিক কলাম নির্বাচন
print(selected_columns)    # ফলাফল দেখানো
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   27
# 2  Charlie   22
# 3    David   32
# 4   Edward   29

# %%
import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

# 'Name', 'Age', এবং 'City' কলাম নির্বাচন
selected_columns = df[['Name', 'Age', 'City']]

# ফলাফল দেখানো
print(selected_columns)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4   Edward   29      Phoenix

# %%
import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
    
}

df = pd.DataFrame(data)

# নতুন কলাম 'Salary' যোগ করা
df['Salary'] = [50000, 60000, 45000, 70000, 65000]

# 'Name', 'Age', 'City', এবং 'Salary' কলাম নির্বাচন
selected_columns = df[['Name', 'Age', 'City', 'Salary']]

# ফলাফল দেখানো
# print(selected_columns)
print(df)
# Out:
#       Name  Age         City  Salary
# 0    Alice   24     New York   50000
# 1      Bob   27  Los Angeles   60000
# 2  Charlie   22      Chicago   45000
# 3    David   32      Houston   70000
# 4   Edward   29      Phoenix   65000

# %%
#  নতুন কলাম 'Salary' যোগ করা and  একাধিক কলাম নির্বাচন
 
import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
    
}

df = pd.DataFrame(data)

# নতুন কলাম 'Salary' যোগ করা
df['Salary'] = [50000, 60000, 45000, 70000, 65000]

# 'Name', 'Age', 'City', এবং 'Salary' কলাম নির্বাচন
selected_columns = df[['Name', 'Age', 'City', 'Salary']]

# ফলাফল দেখানো
# print(selected_columns)
print(df)
# Out:
#       Name  Age         City  Salary
# 0    Alice   24     New York   50000
# 1      Bob   27  Los Angeles   60000
# 2  Charlie   22      Chicago   45000
# 3    David   32      Houston   70000
# 4   Edward   29      Phoenix   65000

# %%
#
import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

# DataFrame দেখানো
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4   Edward   29      Phoenix

# %% [markdown]
# # ১.3 একটি সারি নির্বাচন:

# %%
import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

 


# প্রথম সারি নির্বাচন
first_row = df.iloc[0]
print(first_row)
# Out:
# Name       Alice
# Age           24
# City    New York
# Name: 0, dtype: object

# %%
# name    ,  age   ,      city                         [ aita  holo  heading ]

# Alice     ,  24    ,      New York                     [ aita holo 1st row ]

# %% [markdown]
# ১.4 একাধিক সারি নির্বাচন:

# %%
# প্রথম তিনটি সারি নির্বাচন

import pandas as pd   # import pandas লাইব্রেরি

# ডেটা সেট তৈরি

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

first_three_rows = df.iloc[:3]  # প্রথম তিনটি সারি নির্বাচন

print(first_three_rows)          # ফলাফল দেখানো
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago

# %% [markdown]
# Data Filtering (ডেটা ফিল্টারিং)
# ডেটা ফিল্টারিং হল ডেটা সেটের মধ্যে নির্দিষ্ট শর্ত পূরণ করা সারি বা কলাম নির্বাচন করা।
#
# ৩.1 শর্ত দ্বারা ফিল্টারিং:

# %%
# Age কলামের মান ২৫ এর বেশি এমন সারি নির্বাচন করা
filtered_data = df[df['Age'] > 25]
print(filtered_data)
# Out:
#      Name  Age         City  Salary
# 1     Bob   27  Los Angeles   60000
# 3   David   32      Houston   70000
# 4  Edward   29      Phoenix   65000

# %% [markdown]
# ৩.2 একাধিক শর্ত দ্বারা ফিল্টারিং:

# %%
# Age > 25 এবং City = 'Houston' শর্তে ফিল্টার করা

import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)
 

filtered_data = df[(df['Age'] > 25) & (df['City'] == 'Houston')] # একাধিক শর্তে ফিল্টারিং

print(filtered_data)   # ফলাফল দেখানো
# Out:
#     Name  Age     City
# 3  David   32  Houston

# %%
# Age > 25 এবং City = 'Houston' শর্তে ফিল্টার করা

import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)
 

filtered_data = df[(df['Age'] > 32) & (df['City'] == 'Houston')] # একাধিক শর্তে ফিল্টারিং

print(filtered_data)   # ফলাফল দেখানো
# Out:
# Empty DataFrame
# Columns: [Name, Age, City]
# Index: []

# %%
# CSV ফাইল নিয়ে কাজ করা
# আমি ধরে নিচ্ছি যে আপনাদের কম্পিউটার বা সিস্টেম এ কোন .csv ফাইল নেই, তাই আমরা একটি .csv ফাইল তৈরি করে নেব। বোঝার সুবধার্থে উপরের ডাটাফ্রেমটিকেই ব্যবহার করছি।

 
import pandas as pd
 
data = {"Course ID": ['CSE10', 'CSE20', 'CSE30', 'CSE40'],
        "GPA": [4, 3.68, 3.55,3.98]
}
pd_data = pd.DataFrame(data)
 
pd_data.to_csv('DataFrame.csv', index=False)



# এই প্রোগ্রামটি রান করলেই দেখতে পাবেন যে আপনার ফাইল ডিরেকটরি তে DataFrame নামে একটি .csv ফাইল তৈরি হয়ে গেছে। এই ফাইলটি খুললে দেখতে পাবেন যে এটার ভিতর pd_data এর ভ্যালুগুলোই আছে। এখানে to_csv মেথডটি দিয়ে পানডাস ডাটাফ্রেমকে csv ফাইলে রুপান্তর করা হয়েছে। index কে false করা হয়েছে কারণ আমরা চাইনা যে index এর ভ্যালুও ফাইলে সেভ হোক। আপনারা এটি বাদ দিয়েও চেষ্টা করে দেখতে পারেন।

# যেহেতু আমাদের ফাইল ডিরেক্টরিতে একটি .csv ফাইল আছেই তাই আমরা খুব সহজেই সেই ফাইলটিকে পড়তে পারব। এটার জন্য read_csv() মেথডটি ব্যবহার করব।

# %%
# যেহেতু আমাদের ফাইল ডিরেক্টরিতে একটি .csv ফাইল আছেই তাই আমরা খুব সহজেই সেই ফাইলটিকে পড়তে পারব। এটার জন্য read_csv() মেথডটি ব্যবহার করব।

 
import pandas as pd
 
pd_data = pd.read_csv('DataFrame.csv')
 
print(pd_data)
# Out:
#   Course ID   GPA
# 0     CSE10  4.00
# 1     CSE20  3.68
# 2     CSE30  3.55
# 3     CSE40  3.98

# %%
# লুপ
# পানডাস ডাটাফ্রেম এর ভ্যালু গুলিকে লুপ দিয়ে এক্সেস করা যায়, সেক্ষেত্রে ইচ্ছামত যেকোন কন্ডিশনাল স্টেটমেন্ট দিয়ে কাঙ্খিত ফলাফল পাওয়া যায়।

 
import pandas as pd
 
pd_data = pd.read_csv('DataFrame.csv')
 
for x in pd_data.index:
  if pd_data.loc[x, "GPA"] > 3.9:
    pd_data.loc[x, "GPA"] = 4
 
print(pd_data)
# Out:
#   Course ID   GPA
# 0     CSE10  4.00
# 1     CSE20  3.68
# 2     CSE30  3.55
# 3     CSE40  4.00

# %%
# ১. DataFrame তৈরি

import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

# DataFrame দেখানো
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4   Edward   29      Phoenix

# %%
# প্রথম সারি নির্বাচন
first_row = df.iloc[0]
print(first_row)
# Out:
# Name       Alice
# Age           24
# City    New York
# Name: 0, dtype: object

# %%
# প্রথম সারি নির্বাচন
first_row = df.loc[0]
print(first_row)
# Out:
# Name       Alice
# Age           24
# City    New York
# Name: 0, dtype: object

# %%
# Quick examples showing .loc (label-based) vs .iloc (position-based)
print("Index labels:", df.index.tolist())
print("\nDataFrame:\n", df)

# 1) Single-row access
print("\n--- Single-row ---")
print("df.loc[0] (label 0):\n", df.loc[0])
print("df.iloc[0] (position 0):\n", df.iloc[0])

# 2) Accessing a single cell
print("\n--- Single cell ---")
print("df.loc[0, 'Age'] ->", df.loc[0, 'Age'])
print("df.iloc[0, 1] ->", df.iloc[0, 1])

# 3) Slicing difference: loc end is inclusive, iloc end is exclusive
print("\n--- Slicing ---")
print("df.loc[0:2] (includes label 2):\n", df.loc[0:2])
print("df.iloc[0:2] (excludes position 2):\n", df.iloc[0:2])

# 4) Boolean indexing works naturally with loc
print("\n--- Boolean indexing with loc ---")
print(df.loc[df['Age'] > 25])

# 5) When index labels are integers, loc treats them as labels while iloc uses positions
# (uses existing variable x from the notebook)
print(f"\n--- Label vs position for x={x} ---")
print("df.loc[x]:\n", df.loc[x])
print("df.iloc[x]:\n", df.iloc[x])
# Out:
# Index labels: [0, 1, 2, 3, 4]
#
# DataFrame:
#        Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4   Edward   29      Phoenix
#
# --- Single-row ---
# df.loc[0] (label 0):
#  Name       Alice
# Age           24
# City    New York
# Name: 0, dtype: object
# df.iloc[0] (position 0):
#  Name       Alice
# Age           24
# City    New York
# Name: 0, dtype: object
#
# --- Single cell ---
# df.loc[0, 'Age'] -> 24
# df.iloc[0, 1] -> 24
#
# --- Slicing ---
# df.loc[0:2] (includes label 2):
#        Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# df.iloc[0:2] (excludes position 2):
#      Name  Age         City
# 0  Alice   24     New York
# 1    Bob   27  Los Angeles
#
# --- Boolean indexing with loc ---
#      Name  Age         City
# 1     Bob   27  Los Angeles
# 3   David   32      Houston
# 4  Edward   29      Phoenix
#
# --- Label vs position for x=3 ---
# df.loc[x]:
#  Name      David
# Age          32
# City    Houston
# Name: 3, dtype: object
# df.iloc[x]:
#  Name      David
# Age          32
# City    Houston
# Name: 3, dtype: object

# %%
import pandas as pd

# একটি সিম্পল Series তৈরি করা
data = [10, 20, 30, 40, 50]
series = pd.Series(data)

# সিরিজটি দেখানো
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# Index সহ Series:
# Series তৈরি করতে ইন্ডেক্স প্রদান করা সম্ভব:

# %% [markdown]
# ২. DataFrame:
# DataFrame হল একটি দ্বিমাত্রিক (2D) টেবিল ডেটা স্ট্রাকচার, যা কলাম এবং সারি নিয়ে গঠিত। এটি এক বা একাধিক Series এর সমষ্টি, এবং প্রতিটি Series একটি নির্দিষ্ট কলাম প্রতিনিধিত্ব করে।
#
# মৌলিক বৈশিষ্ট্য:
# এটি একাধিক কলাম ধারণ করতে পারে, যেখানে প্রতিটি কলাম একটি Series।
# প্রতিটি কলামের জন্য একটি আলাদা index থাকতে পারে।
# DataFrame সাধারণত ডেটা বিশ্লেষণ, টেবিল আকারে ডেটা দেখানো এবং পরিচালনার জন্য ব্যবহৃত হয়।
#
# Copied from SATT ACADEMY. Visit us at: https://sattacademy.com

# %%
import pandas as pd

# ডেটার একটি dictionary তৈরি করা
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

# DataFrame তৈরি করা
df = pd.DataFrame(data)

# DataFrame প্রদর্শন
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4      Eva   29      Phoenix

# %% [markdown]
# এখানে, DataFrame তে তিনটি কলাম (Name, Age, City) এবং পাঁচটি সারি রয়েছে। প্রতিটি কলামের একটি নাম (যেমন, "Name", "Age", "City") এবং প্রতিটি সারির একটি ইন্ডেক্স (0, 1, 2, 3, 4) রয়েছে।
#
# Index সহ DataFrame:
# DataFrame এ কলামের নাম এবং সারির ইন্ডেক্স কাস্টমাইজ করা যেতে পারে:
#
# Copied from SATT ACADEMY. Visit us at: https://sattacademy.com

# %%
df_custom_index = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e'])
print(df_custom_index)
# Out:
#       Name  Age         City
# a    Alice   24     New York
# b      Bob   27  Los Angeles
# c  Charlie   22      Chicago
# d    David   32      Houston
# e      Eva   29      Phoenix

# %%
# DataFrame তৈরি
# প্রথমে একটি সাধারণ DataFrame তৈরি করি:

import pandas as pd

# ডেটা সেট তৈরি
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Edward'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

# DataFrame দেখানো
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# 4   Edward   29      Phoenix

# %%
# ২. Data Selection (ডেটা নির্বাচন)
# DataFrame থেকে নির্দিষ্ট কলাম বা সারি নির্বাচন করার বিভিন্ন পদ্ধতি আছে।

# ১.1 একটি কলাম নির্বাচন:
# 'Name' কলাম নির্বাচন
name_column = df['Name']
print(name_column)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4     Edward
# Name: Name, dtype: object

# %%
# একাধিক কলাম নির্বাচন:
# 'Name' এবং 'Age' কলাম নির্বাচন
selected_columns = df[['Name', 'Age']]
print(selected_columns)
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   27
# 2  Charlie   22
# 3    David   32
# 4   Edward   29

# %%
# ৩. groupby() ফাংশনের ব্যবহার

import pandas as pd

# উদাহরণ ডেটা তৈরি
data = {
    'Department': ['HR', 'IT', 'HR', 'IT', 'Sales', 'Sales', 'IT', 'HR'],
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hank'],
    'Sales': [200, 300, 150, 400, 500, 600, 350, 250]
}

df = pd.DataFrame(data)

# 'Department' অনুযায়ী ডেটা গ্রুপ করা এবং গড় বিক্রয় বের করা
grouped = df.groupby('Department')['Sales'].mean()

print(grouped)
# Out:
# Department
# HR       200.0
# IT       350.0
# Sales    550.0
# Name: Sales, dtype: float64

# %%
# ৩. groupby() ফাংশনের ব্যবহার

import pandas as pd

# উদাহরণ ডেটা তৈরি
data = {
    'Department': ['HR', 'IT', 'HR', 'IT', 'Sales', 'Sales', 'IT', 'HR'],
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hank'],
    'Sales': [200, 300, 150, 400, 500, 600, 350, 250]
}

df = pd.DataFrame(data)

# 'Department' অনুযায়ী ডেটা গ্রুপ করা এবং গড় বিক্রয় বের করা
grouped = df.groupby('Department')['Sales'].mean()

print(grouped)
# Out:
# Department
# HR       200.0
# IT       350.0
# Sales    550.0
# Name: Sales, dtype: float64
